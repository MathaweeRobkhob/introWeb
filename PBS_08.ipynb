# %% [markdown]
# <a href="https://colab.research.google.com/github/MathaweeRobkhob/introWeb/blob/main/PBS_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##### Code-00 #####

import matplotlib.pyplot as plt
import networkx as nx

G = nx.dodecahedral_graph()
#draw graph
nx.draw(G, with_labels=True, font_color='yellow', node_size=2000 )
plt.show()

# %%
##### Code-01 #####
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph() #Create Graph

G.add_node('A')
G.add_edge('B','C')
G.add_edge('A','B')
G.add_edge('A','C')
#draw graph
nx.draw(G, with_labels=True,font_color='yellow',node_size=2000)
plt.show()

# %%
##### Code-02 #####
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph()

G.add_edge('man', 'baby', weight=1)
G.add_edge('baby', 'woman', weight=0.5)
G.add_edge('man', 'woman', weight=0.3)
G.add_edge('woman', 'year', weight=1)
G.add_edge('year', 'man', weight=1)

#draw graph
nx.draw(G, with_labels=True,font_color='yellow',node_size=2000)
plt.show()

# %%
##### Code-03 #####
import networkx as nx
import matplotlib.pyplot as plot

G = nx.Graph()

G.add_edge('man', 'baby', weight=1)
G.add_edge('baby', 'woman', weight=0.5)
G.add_edge('man', 'woman', weight=0.3)
G.add_edge('woman', 'year', weight=1)
G.add_edge('year', 'man', weight=1)

edge_labels = nx.get_edge_attributes(G, 'weight')
print(edge_labels)

#draw graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True,font_color='yellow',node_size=2000)
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
plt.show()
# Out:
# {('man', 'baby'): 1, ('man', 'woman'): 0.3, ('man', 'year'): 1, ('baby', 'woman'): 0.5, ('woman', 'year'): 1}

# %%
##### Code-04 #####
import networkx as nx
import matplotlib.pyplot as plot

G = nx.Graph()

G.add_edge('man', 'baby', weight=1)
G.add_edge('baby', 'woman', weight=0.5)
G.add_edge('man', 'woman', weight=0.3)
G.add_edge('woman', 'year', weight=1)
G.add_edge('year', 'man', weight=1)

print('Shortest path from baby to man is :',
      nx.shortest_path(G, source='baby', target='man', weight='weight' ))
print('Shortest path lenght from baby to man is :',
      nx.shortest_path_length(G, source='baby', target='man', weight='weight' ))

#draw graph
edge_labels = nx.get_edge_attributes(G, 'weight')
print(edge_labels)
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True,font_color='yellow',node_size=2000)
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
plt.show()
# Out:
# Shortest path from baby to man is : ['baby', 'woman', 'man']
# Shortest path lenght from baby to man is : 0.8
# {('man', 'baby'): 1, ('man', 'woman'): 0.3, ('man', 'year'): 1, ('baby', 'woman'): 0.5, ('woman', 'year'): 1}

# %%
##### Code-05 #####
import networkx as nx
import matplotlib.pyplot as plot

G = nx.Graph()

G.add_edge('man', 'baby', weight=1)
G.add_edge('baby', 'woman', weight=0.5)
G.add_edge('man', 'woman', weight=0.3)
G.add_edge('woman', 'year', weight=1)
G.add_edge('year', 'man', weight=1)

final_avg = 999999999.99
final_key = ''
#final node shortest path to all node
node_allSP = dict(nx.shortest_path_length(G, weight='weight'))
print(node_allSP)
for key in node_allSP:
    avg_nodeSP = sum(node_allSP[key].values())/(len(node_allSP[key]) - 1)
    print('AverageSP to all nodes :', key, ' is ' , avg_nodeSP)
    if final_avg > avg_nodeSP:
      final_avg = avg_nodeSP
      final_key = key

print('The centroid is :', final_key, 'the length is' ,final_avg)
#draw graph
edge_labels = nx.get_edge_attributes(G, 'weight')
print(edge_labels)
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True,font_color='yellow',node_size=2000)
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
plt.show()
# Out:
# {'man': {'man': 0, 'woman': 0.3, 'baby': 0.8, 'year': 1}, 'baby': {'baby': 0, 'woman': 0.5, 'man': 0.8, 'year': 1.5}, 'woman': {'woman': 0, 'man': 0.3, 'baby': 0.5, 'year': 1}, 'year': {'year': 0, 'woman': 1, 'man': 1, 'baby': 1.5}}
# AverageSP to all nodes : man  is  0.7000000000000001
# AverageSP to all nodes : baby  is  0.9333333333333332
# AverageSP to all nodes : woman  is  0.6
# AverageSP to all nodes : year  is  1.1666666666666667
# The centroid is : woman the length is 0.6
# {('man', 'baby'): 1, ('man', 'woman'): 0.3, ('man', 'year'): 1, ('baby', 'woman'): 0.5, ('woman', 'year'): 1}

# %%
##### Code-06 #####
import networkx as nx
import matplotlib.pyplot as plot

G = nx.Graph()
G.add_edges_from([('A', 'B'), ('A', 'M'), ('A', 'L'), ('B', 'C'), ('B', 'D'),
                  ('B', 'N'), ('B', 'O'), ('C', 'D'), ('D', 'E'), ('D', 'O'),
                  ('E', 'F'), ('F', 'G'), ('F', 'N'), ('G', 'H'), ('H', 'N'),
                  ('H', 'I'), ('H', 'P'), ('P', 'O'), ('P', 'I'), ('P', 'M'),
                  ('I', 'J'), ('J', 'K'), ('K', 'M'), ('K', 'L')])

print('Shoetest path from E to L is :',
      nx.shortest_path(G, source='E', target='L'))
final_avg = 999999999.99
final_key = ''
#final node shortest path to all node
node_allSP = dict(nx.shortest_path_length(G, weight='weight'))
print(node_allSP)
for key in node_allSP:
    avg_nodeSP = sum(node_allSP[key].values())/(len(node_allSP[key]) - 1)
    print('AverageSP to all nodes :', key, ' is ' , avg_nodeSP)
    if final_avg > avg_nodeSP:
      final_avg = avg_nodeSP
      final_key = key

print('The centroid is :', final_key, 'the length is' ,final_avg)

#draw graph
nx.draw(G, with_labels=True,font_color='yellow',node_size=1500)
plt.show()
# Out:
# Shoetest path from E to L is : ['E', 'D', 'B', 'A', 'L']
'L': 3, 'E': 4, 'C': 4}, 'P': {'P': 0, 'H': 1, 'O': 1, 'I': 1, 'M': 1, 'G': 2, 'N': 2, 'B': 2, 'D': 2, 'J': 2, 'A': 2, 'K': 2, 'F': 3, 'C': 3, 'E': 3, 'L': 3}, 'J': {'J': 0, 'I': 1, 'K': 1, 'H': 2, 'P': 2, 'M': 2, 'L': 2, 'G': 3, 'N': 3, 'O': 3, 'A': 3, 'F': 4, 'B': 4, 'D': 4, 'E': 5, 'C': 5}, 'K': {'K': 0, 'J': 1, 'M': 1, 'L': 1, 'I': 2, 'A': 2, 'P': 2, 'H': 3, 'B': 3, 'O': 3, 'G': 4, 'N': 4, 'C': 4, 'D': 4, 'F': 5, 'E': 5}}
# AverageSP to all nodes : A  is  2.2666666666666666
# AverageSP to all nodes : B  is  2.0
# AverageSP to all nodes : M  is  2.3333333333333335
# AverageSP to all nodes : L  is  2.8666666666666667
# AverageSP to all nodes : C  is  2.8
# AverageSP to all nodes : D  is  2.3333333333333335
# AverageSP to all nodes : N  is  2.1333333333333333
# AverageSP to all nodes : O  is  2.1333333333333333
# AverageSP to all nodes : E  is  2.8666666666666667
# AverageSP to all nodes : F  is  2.7333333333333334
# AverageSP to all nodes : G  is  2.8
# AverageSP to all nodes : H  is  2.2
# AverageSP to all nodes : I  is  2.4
# AverageSP to all nodes : P  is  2.0
# AverageSP to all nodes : J  is  2.933333333333333
# AverageSP to all nodes : K  is  2.933333333333333
# The centroid is : B the length is 2.0

# %%
##### Code-07 #####
import networkx as nx
import matplotlib.pyplot as plot

G = nx.Graph()
G.add_edges_from([('A', 'B'), ('A', 'M'), ('A', 'L'), ('B', 'C'), ('B', 'D'),
                  ('B', 'N'), ('B', 'O'), ('C', 'D'), ('D', 'E'), ('D', 'O'),
                  ('E', 'F'), ('F', 'G'), ('F', 'N'), ('G', 'H'), ('H', 'N'),
                  ('H', 'I'), ('H', 'P'), ('P', 'O'), ('P', 'I'), ('P', 'M'),
                  ('I', 'J'), ('J', 'K'), ('K', 'M'), ('K', 'L')])

print('Shoetest path from E to L is :',
      nx.shortest_path(G, source='E', target='L'))

print('A neighbors')
Alist = nx.all_neighbors(G,'A')
for k in Alist:
  print(k)

print('E neighbors')
Elist = nx.all_neighbors(G,'E')
for k in Elist:
  print(k)

print('I neighbors')
Ilist = nx.all_neighbors(G,'I')
for k in Ilist:
  print(k)

print('Shoetest path from O to A is :',
      nx.shortest_path_length(G, source='O', target='A'))
# Out:
# Shoetest path from E to L is : ['E', 'D', 'B', 'A', 'L']
# A neighbors
# B
# M
# L
# E neighbors
# D
# F
# I neighbors
# H
# P
# J
# Shoetest path from O to A is : 2
